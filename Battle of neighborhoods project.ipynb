# %% [markdown]
# <h2 id="about_project">This is notebook is created for capstone project on the Battle of neighborhoods </h2>

# %% [markdown]
# Compare different neighborhoods in terms of a service, cause of complaints in another neighborhood, or anything else related to neighborhoods. Hence the name of the capstone project is the battle of the neighborhoods
# In this project, given a city like the City of Toronto, I am segmenting it into different neighborhoods using the geographical coordinates of the center of each neighborhood. And then, using a combination of location data and machine learning, I am grouping the neighborhoods into clusters.

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
